# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np

py.init_notebook_mode(connected=True)

plt.figure(figsize=(25,7))
confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
confirmed_per_country = confirmed.groupby("Country/Region").sum()
confirmed_per_country.loc["Brazil"][2:].diff().dropna().plot(marker = 'o')
#plt.ylim(0, 11000)
plt.title("Casos confirmados no Brasil")
plt.show()
#plt.savefig("COVID_DAYS_LINE.png")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
last_date = "5/10/21"
plt.figure(figsize=(37,12,))
confirmed_per_country[last_date].sort_values(ascending=False)[0:10].plot(kind = 'bar', facecolor='#9999ff', edgecolor='white')
plt.title("Confirmados por País")
plt.rcParams['xtick.labelsize'] = 25
plt.rcParams['ytick.labelsize'] = 15
#plt.savefig("COVID_PAIS.png")
plt.show()

# %%
plt.figure(figsize=(55,22,))
confirmed_per_country.loc["Brazil"][300:].diff().dropna().plot(kind = "bar", facecolor = "#CC0066")
plt.rcParams['xtick.labelsize'] = 40
plt.rcParams['ytick.labelsize'] = 30

plt.show()
#plt.savefig("COVID_DAYS.png")

# %%
confirmed_per_country[last_date].sort_values(ascending=False)[0:30]
# Out:
# Country/Region
# US                32745255
# India             22992517
# Brazil            15209990
# France             5841593
# Turkey             5044936
# Russia             4832959
# United Kingdom     4452956
# Italy              4116287
# Spain              3581392
# Germany            3538208
# Argentina          3165121
# Colombia           3015301
# Poland             2835083
# Iran               2673219
# Mexico             2366496
# Ukraine            2178095
# Peru               1850290
# Indonesia          1718575
# Czechia            1645448
# South Africa       1597724
# Netherlands        1592742
# Canada             1302489
# Chile              1252808
# Iraq               1117627
# Philippines        1108826
# Romania            1066731
# Belgium            1017876
# Sweden             1007792
# Pakistan            864557
# Portugal            839740
# Name: 5/10/21, dtype: int64

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat  ...  5/9/21  5/10/21  5/11/21
# 0            NaN    Afghanistan  33.93911  ...   61842    62063    62403
# 1            NaN        Albania  41.15330  ...  131723   131753   131803
# 2            NaN        Algeria  28.03390  ...  124104   124288   124483
# 3            NaN        Andorra  42.50630  ...   13423    13429    13447
# 4            NaN         Angola -11.20270  ...   28740    28875    29146
#
# [5 rows x 480 columns]
